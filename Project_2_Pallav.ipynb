# %%
# Necessary libraries imported here
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/HRDataset_v14.csv')
df.head(15)
# Out:
#                Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0        Adinolfi, Wilson  K  10026          0                0         1
# 1   Ait Sidi, Karthikeyan     10084          1                1         1
# 2          Akinkuolie, Sarah  10196          1                1         0
# 3               Alagbe,Trina  10088          1                1         0
# 4           Anderson, Carol   10069          0                2         0
# 5          Anderson, Linda    10002          0                0         0
# 6            Andreola, Colby  10194          0                0         0
# 7                Athwal, Sam  10062          0                4         1
# 8           Bachiochi, Linda  10114          0                0         0
# 9         Bacong, Alejandro   10250          0                2         1
# 10      Baczenski, Rachael    10252          1                1         0
# 11           Barbara, Thomas  10242          1                1         1
# ...

# %%
#check if there is any missing values or error in the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %%
df.describe()
# Out:
#               EmpID   MarriedID  MaritalStatusID    GenderID  EmpStatusID  \
# count    311.000000  311.000000       311.000000  311.000000   311.000000
# mean   10156.000000    0.398714         0.810289    0.434084     2.392283
# std       89.922189    0.490423         0.943239    0.496435     1.794383
# min    10001.000000    0.000000         0.000000    0.000000     1.000000
# 25%    10078.500000    0.000000         0.000000    0.000000     1.000000
# 50%    10156.000000    0.000000         1.000000    0.000000     1.000000
# 75%    10233.500000    1.000000         1.000000    1.000000     5.000000
# max    10311.000000    1.000000         4.000000    1.000000     5.000000
#
#            DeptID  PerfScoreID  FromDiversityJobFairID         Salary  \
# count  311.000000   311.000000              311.000000     311.000000
# mean     4.610932     2.977492                0.093248   69020.684887
# std      1.083487     0.587072                0.291248   25156.636930
# ...

# %% [markdown]
# - ManagerID has some missing values.
# - we can drop the column managerID cuz the column is not required for analysis (too many redundant values)
# - we will drop unnecessary columns like 'ManagerID','DateofHire','DateofHire.1','HispanicLatino','GenderID','Zip','DOB','CitizenDesc','ManagerName','MarriedID','MaritalStatusID','PositionID'

# %%
df[['Employee_Name','GenderID']].head(15)
# Out:
#                Employee_Name  GenderID
# 0        Adinolfi, Wilson  K         1
# 1   Ait Sidi, Karthikeyan            1
# 2          Akinkuolie, Sarah         0
# 3               Alagbe,Trina         0
# 4           Anderson, Carol          0
# 5          Anderson, Linda           0
# 6            Andreola, Colby         0
# 7                Athwal, Sam         1
# 8           Bachiochi, Linda         0
# 9         Bacong, Alejandro          1
# 10      Baczenski, Rachael           0
# 11           Barbara, Thomas         1
# 12          Barbossa, Hector         1
# 13      Barone, Francesco  A         1
# 14             Barton, Nader         1

# %% [markdown]
# - As we can see in GenderID, 1 represents 'Male' & 0 represents 'Female'

# %%
df[['Employee_Name','EmploymentStatus']].head(15)
# Out:
#                Employee_Name        EmploymentStatus
# 0        Adinolfi, Wilson  K                  Active
# 1   Ait Sidi, Karthikeyan     Voluntarily Terminated
# 2          Akinkuolie, Sarah  Voluntarily Terminated
# 3               Alagbe,Trina                  Active
# 4           Anderson, Carol   Voluntarily Terminated
# 5          Anderson, Linda                    Active
# 6            Andreola, Colby                  Active
# 7                Athwal, Sam                  Active
# 8           Bachiochi, Linda                  Active
# 9         Bacong, Alejandro                   Active
# 10      Baczenski, Rachael    Voluntarily Terminated
# 11           Barbara, Thomas  Voluntarily Terminated
# 12          Barbossa, Hector                  Active
# 13      Barone, Francesco  A                  Active
# 14             Barton, Nader  Voluntarily Terminated

# %%
df[['Employee_Name','Position','PositionID']].head(15)
# Out:
#                Employee_Name                  Position  PositionID
# 0        Adinolfi, Wilson  K   Production Technician I          19
# 1   Ait Sidi, Karthikeyan                      Sr. DBA          27
# 2          Akinkuolie, Sarah  Production Technician II          20
# 3               Alagbe,Trina   Production Technician I          19
# 4           Anderson, Carol    Production Technician I          19
# 5          Anderson, Linda     Production Technician I          19
# 6            Andreola, Colby         Software Engineer          24
# 7                Athwal, Sam   Production Technician I          19
# 8           Bachiochi, Linda   Production Technician I          19
# 9         Bacong, Alejandro                 IT Support          14
# 10      Baczenski, Rachael     Production Technician I          19
# 11           Barbara, Thomas   Production Technician I          19
# 12          Barbossa, Hector              Data Analyst           9
# ...

# %%
df[['Employee_Name','TermReason']].head(15)
# Out:
#                Employee_Name         TermReason
# 0        Adinolfi, Wilson  K  N/A-StillEmployed
# 1   Ait Sidi, Karthikeyan         career change
# 2          Akinkuolie, Sarah              hours
# 3               Alagbe,Trina  N/A-StillEmployed
# 4           Anderson, Carol    return to school
# 5          Anderson, Linda    N/A-StillEmployed
# 6            Andreola, Colby  N/A-StillEmployed
# 7                Athwal, Sam  N/A-StillEmployed
# 8           Bachiochi, Linda  N/A-StillEmployed
# 9         Bacong, Alejandro   N/A-StillEmployed
# 10      Baczenski, Rachael     Another position
# 11           Barbara, Thomas            unhappy
# 12          Barbossa, Hector  N/A-StillEmployed
# 13      Barone, Francesco  A  N/A-StillEmployed
# 14             Barton, Nader   Another position

# %%
df[['Employee_Name','Absences']].head(15)
# Out:
#                Employee_Name  Absences
# 0        Adinolfi, Wilson  K         1
# 1   Ait Sidi, Karthikeyan           17
# 2          Akinkuolie, Sarah         3
# 3               Alagbe,Trina        15
# 4           Anderson, Carol          2
# 5          Anderson, Linda          15
# 6            Andreola, Colby        19
# 7                Athwal, Sam        19
# 8           Bachiochi, Linda         4
# 9         Bacong, Alejandro         16
# 10      Baczenski, Rachael          12
# 11           Barbara, Thomas        15
# 12          Barbossa, Hector         9
# 13      Barone, Francesco  A         7
# 14             Barton, Nader         1

# %%
df[['Employee_Name','PerformanceScore']].head(15)
# Out:
#                Employee_Name PerformanceScore
# 0        Adinolfi, Wilson  K          Exceeds
# 1   Ait Sidi, Karthikeyan         Fully Meets
# 2          Akinkuolie, Sarah      Fully Meets
# 3               Alagbe,Trina      Fully Meets
# 4           Anderson, Carol       Fully Meets
# 5          Anderson, Linda            Exceeds
# 6            Andreola, Colby      Fully Meets
# 7                Athwal, Sam      Fully Meets
# 8           Bachiochi, Linda      Fully Meets
# 9         Bacong, Alejandro       Fully Meets
# 10      Baczenski, Rachael        Fully Meets
# 11           Barbara, Thomas      Fully Meets
# 12          Barbossa, Hector          Exceeds
# 13      Barone, Francesco  A      Fully Meets
# 14             Barton, Nader      Fully Meets

# %%
df[['Employee_Name','CitizenDesc']].head(15)
# Out:
#                Employee_Name CitizenDesc
# 0        Adinolfi, Wilson  K  US Citizen
# 1   Ait Sidi, Karthikeyan     US Citizen
# 2          Akinkuolie, Sarah  US Citizen
# 3               Alagbe,Trina  US Citizen
# 4           Anderson, Carol   US Citizen
# 5          Anderson, Linda    US Citizen
# 6            Andreola, Colby  US Citizen
# 7                Athwal, Sam  US Citizen
# 8           Bachiochi, Linda  US Citizen
# 9         Bacong, Alejandro   US Citizen
# 10      Baczenski, Rachael    US Citizen
# 11           Barbara, Thomas  US Citizen
# 12          Barbossa, Hector  US Citizen
# 13      Barone, Francesco  A  US Citizen
# 14             Barton, Nader  US Citizen

# %%
df[['Employee_Name','MaritalDesc']].head(15)
# Out:
#                Employee_Name MaritalDesc
# 0        Adinolfi, Wilson  K      Single
# 1   Ait Sidi, Karthikeyan        Married
# 2          Akinkuolie, Sarah     Married
# 3               Alagbe,Trina     Married
# 4           Anderson, Carol     Divorced
# 5          Anderson, Linda        Single
# 6            Andreola, Colby      Single
# 7                Athwal, Sam     Widowed
# 8           Bachiochi, Linda      Single
# 9         Bacong, Alejandro     Divorced
# 10      Baczenski, Rachael       Married
# 11           Barbara, Thomas     Married
# 12          Barbossa, Hector    Divorced
# 13      Barone, Francesco  A      Single
# 14             Barton, Nader    Divorced

# %%
df[['Employee_Name','Sex']].head(15)
# Out:
#                Employee_Name Sex
# 0        Adinolfi, Wilson  K  M
# 1   Ait Sidi, Karthikeyan     M
# 2          Akinkuolie, Sarah   F
# 3               Alagbe,Trina   F
# 4           Anderson, Carol    F
# 5          Anderson, Linda     F
# 6            Andreola, Colby   F
# 7                Athwal, Sam  M
# 8           Bachiochi, Linda   F
# 9         Bacong, Alejandro   M
# 10      Baczenski, Rachael     F
# 11           Barbara, Thomas  M
# 12          Barbossa, Hector  M
# 13      Barone, Francesco  A  M
# 14             Barton, Nader  M

# %%
df[['Employee_Name','MarriedID','MaritalStatusID','MaritalDesc']].head(15)
# Out:
#                Employee_Name  MarriedID  MaritalStatusID MaritalDesc
# 0        Adinolfi, Wilson  K          0                0      Single
# 1   Ait Sidi, Karthikeyan             1                1     Married
# 2          Akinkuolie, Sarah          1                1     Married
# 3               Alagbe,Trina          1                1     Married
# 4           Anderson, Carol           0                2    Divorced
# 5          Anderson, Linda            0                0      Single
# 6            Andreola, Colby          0                0      Single
# 7                Athwal, Sam          0                4     Widowed
# 8           Bachiochi, Linda          0                0      Single
# 9         Bacong, Alejandro           0                2    Divorced
# 10      Baczenski, Rachael            1                1     Married
# 11           Barbara, Thomas          1                1     Married
# 12          Barbossa, Hector          0                2    Divorced
# ...

# %%
df[['Employee_Name','DateofHire','DateofHire.1','HispanicLatino','Termd','TermReason']].head(15)
# Out:
#                Employee_Name  DateofHire DateofHire.1 HispanicLatino  Termd  \
# 0        Adinolfi, Wilson  K  07-05-2011   08-05-2011             No      0
# 1   Ait Sidi, Karthikeyan      3/30/2015    3/30/2016             No      1
# 2          Akinkuolie, Sarah  07-05-2011   08-05-2011             No      1
# 3               Alagbe,Trina  01-07-2008   02-07-2008             No      0
# 4           Anderson, Carol   07-11-2011   08-11-2011             No      1
# 5          Anderson, Linda    01-09-2012   02-09-2012             No      0
# 6            Andreola, Colby  11-10-2014   12-10-2014             No      0
# 7                Athwal, Sam   9/30/2013    9/30/2014             No      0
# 8           Bachiochi, Linda  07-06-2009   08-06-2009             No      0
# 9         Bacong, Alejandro   01-05-2015   02-05-2015             No      0
# 10      Baczenski, Rachael    01-10-2011   02-10-2011            Yes      1
# ...

# %%
df[['Employee_Name','EmpID','EmpStatusID','EmploymentStatus','EngagementSurvey','DaysLateLast30']].head(15)
# Out:
#                Employee_Name  EmpID  EmpStatusID        EmploymentStatus  \
# 0        Adinolfi, Wilson  K  10026            1                  Active
# 1   Ait Sidi, Karthikeyan     10084            5  Voluntarily Terminated
# 2          Akinkuolie, Sarah  10196            5  Voluntarily Terminated
# 3               Alagbe,Trina  10088            1                  Active
# 4           Anderson, Carol   10069            5  Voluntarily Terminated
# 5          Anderson, Linda    10002            1                  Active
# 6            Andreola, Colby  10194            1                  Active
# 7                Athwal, Sam  10062            1                  Active
# 8           Bachiochi, Linda  10114            3                  Active
# 9         Bacong, Alejandro   10250            1                  Active
# 10      Baczenski, Rachael    10252            5  Voluntarily Terminated
# 11           Barbara, Thomas  10242            5  Voluntarily Terminated
# ...

# %%
df[['Employee_Name','State','EmpSatisfaction','SpecialProjectsCount','LastPerformanceReview_Date']].head(15)
# Out:
#                Employee_Name State  EmpSatisfaction  SpecialProjectsCount  \
# 0        Adinolfi, Wilson  K    MA                5                     0
# 1   Ait Sidi, Karthikeyan       MA                3                     6
# 2          Akinkuolie, Sarah    MA                3                     0
# 3               Alagbe,Trina    MA                5                     0
# 4           Anderson, Carol     MA                4                     0
# 5          Anderson, Linda      MA                5                     0
# 6            Andreola, Colby    MA                3                     4
# 7                Athwal, Sam    MA                4                     0
# 8           Bachiochi, Linda    MA                3                     0
# 9         Bacong, Alejandro     MA                5                     6
# 10      Baczenski, Rachael      MA                4                     0
# 11           Barbara, Thomas    MA                3                     0
# ...

# %%
df[['Employee_Name','Salary','SpecialProjectsCount','Position']].head(15)
# Out:
#                Employee_Name  Salary  SpecialProjectsCount  \
# 0        Adinolfi, Wilson  K   62506                     0
# 1   Ait Sidi, Karthikeyan     104437                     6
# 2          Akinkuolie, Sarah   64955                     0
# 3               Alagbe,Trina   64991                     0
# 4           Anderson, Carol    50825                     0
# 5          Anderson, Linda     57568                     0
# 6            Andreola, Colby   95660                     4
# 7                Athwal, Sam   59365                     0
# 8           Bachiochi, Linda   47837                     0
# 9         Bacong, Alejandro    50178                     6
# 10      Baczenski, Rachael     54670                     0
# 11           Barbara, Thomas   47211                     0
# 12          Barbossa, Hector   92328                     5
# 13      Barone, Francesco  A   58709                     0
# 14             Barton, Nader   52505                     0
#
# ...

# %%
df = df.drop(['State','LastPerformanceReview_Date','EmpID','DaysLateLast30','EmpStatusID','Termd','FromDiversityJobFairID','DeptID','ManagerID','DateofHire','DateofHire.1','HispanicLatino','Zip','DOB','CitizenDesc','ManagerName','MarriedID','MaritalStatusID','PositionID'], axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Employee_Name         311 non-null    object
#  1   GenderID              311 non-null    int64
#  2   PerfScoreID           311 non-null    int64
#  3   Salary                311 non-null    int64
#  4   Position              311 non-null    object
#  5   Sex                   311 non-null    object
#  6   MaritalDesc           311 non-null    object
#  7   TermReason            311 non-null    object
#  8   EmploymentStatus      311 non-null    object
#  9   Department            311 non-null    object
#  10  RecruitmentSource     311 non-null    object
#  11  PerformanceScore      311 non-null    object
#  12  EngagementSurvey      311 non-null    float64
#  13  EmpSatisfaction       311 non-null    int64
#  14  SpecialProjectsCount  311 non-null    int64
# ...

# %% [markdown]
# - The final data has been processed
# - removed missing values.
# - dropped unnecessary columns like 'State','LastPerformanceReview_Date','EmpID','DaysLateLast30','EmpStatusID','Termd','FromDiversityJobFairID','PerfScoreID','DeptID','ManagerID','DateofHire','DateofHire.1','HispanicLatino','GenderID','Zip','DOB','CitizenDesc','ManagerName','MarriedID','MaritalStatusID','PositionID'

# %%
# Now we will check the correlation between the remaining data.

#HEATMAP
fig = plt.figure(figsize=(8,6))
g = sns.heatmap(df.corr(), annot=True);
g.set_title('correlation between employee data')
# Out:
# <ipython-input-70-4e9ceb99ca22>:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   g = sns.heatmap(df.corr(), annot=True);
# Text(0.5, 1.0, 'correlation between employee data')

# %% [markdown]
# - As we can see there is positive strong correlation betweeen Salary & SpecialProjectCount column.
# - A week positive correlation between EngagementSurvey & EmpSatisfaction.
# - other column have very weak correlation with each other which is negligible.

# %%
# Now that we have all the necessary columns that we need. we can do our data vizualization.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Employee_Name         311 non-null    object
#  1   GenderID              311 non-null    int64
#  2   PerfScoreID           311 non-null    int64
#  3   Salary                311 non-null    int64
#  4   Position              311 non-null    object
#  5   Sex                   311 non-null    object
#  6   MaritalDesc           311 non-null    object
#  7   TermReason            311 non-null    object
#  8   EmploymentStatus      311 non-null    object
#  9   Department            311 non-null    object
#  10  RecruitmentSource     311 non-null    object
#  11  PerformanceScore      311 non-null    object
#  12  EngagementSurvey      311 non-null    float64
#  13  EmpSatisfaction       311 non-null    int64
#  14  SpecialProjectsCount  311 non-null    int64
# ...

# %%
df['PerformanceScore'].hist()
# Out:
# <Axes: >

# %% [markdown]
# - The majority of Employee have performance score in 'Fully Meets' category

# %%
plt.barh(grouped.index, grouped['Salary'])
# Out:
# <BarContainer object of 32 artists>

# %% [markdown]
# - Through above plot we can see there is highest number of employement in Production technician 1 and 2.

# %%
figscale = 1
df['Salary'].plot(kind='hist', bins=30, title='Salary Distribution', figsize=(8*figscale, 4*figscale))
# Out:
# <Axes: title={'center': 'Salary Distribution'}, ylabel='Frequency'>

# %% [markdown]
# - The salary Distribution is skewed, with the high majority of employees havvuing salary between 50,000 to 100,000.

# %%
sns.boxplot(data = df, x='Salary', y="PerformanceScore")
# Out:
# <Axes: xlabel='Salary', ylabel='PerformanceScore'>

# %% [markdown]
# - From above we can conclued that people with salary 1,00,000 or above thy are performing as expected by fullfiling their jobs and tasks.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Employee_Name         311 non-null    object
#  1   GenderID              311 non-null    int64
#  2   PerfScoreID           311 non-null    int64
#  3   Salary                311 non-null    int64
#  4   Position              311 non-null    object
#  5   Sex                   311 non-null    object
#  6   MaritalDesc           311 non-null    object
#  7   TermReason            311 non-null    object
#  8   EmploymentStatus      311 non-null    object
#  9   Department            311 non-null    object
#  10  RecruitmentSource     311 non-null    object
#  11  PerformanceScore      311 non-null    object
#  12  EngagementSurvey      311 non-null    float64
#  13  EmpSatisfaction       311 non-null    int64
#  14  SpecialProjectsCount  311 non-null    int64
# ...

# %%
sns.boxplot(data=df, x="PerformanceScore", y="EngagementSurvey")
# Out:
# <Axes: xlabel='PerformanceScore', ylabel='EngagementSurvey'>

# %% [markdown]
# - Higher performing employes are tend to have higher engagement scores

# %%
df.groupby('Department')['EmpSatisfaction'].mean().plot.bar()
# Out:
# <Axes: xlabel='Department'>

# %% [markdown]
# - Employee satisfaction level vary across departments, suggesting potential difference in work environment and managemnet effectiveness.

# %%
plt.figure(figsize = (18, 6))

sns.countplot( x ="RecruitmentSource", data=df)
# Out:
# <Axes: xlabel='RecruitmentSource', ylabel='count'>

# %% [markdown]
# - from above plot we can se the company hired most of the employees vary different platforms. but Indeed and Linkedin is common with higher number of engagements.

# %%
sns.countplot(data=df, x='Sex')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %% [markdown]
# - Above plot display the total number of gender within the department, enabling the organization to address diversity and inclusion initiative effectively.

# %%
sns.swarmplot(x='Sex', y='Salary', data=df)
plt.xlabel("Gender")
plt.ylabel("Salary")
# Out:
# Text(12.097222222222216, 0.5, 'Salary')
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 6.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# By Above plot we can see that there are few number of female with Salary higher than 2,00,000.

# %% [markdown]
# What is the variety of Marital status of the company's employees?

# %%
df['MaritalDesc'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# it looks like majority of employees are single or married but how many of them are still active ?

# %%
plt.figure(figsize=(16, 6))
sns.countplot(x=df['EmploymentStatus'], hue=df['MaritalDesc'])
# Out:
# <Axes: xlabel='EmploymentStatus', ylabel='count'>

# %% [markdown]
# - Looks like majority of employees are single and active working. Most of the people who were divorced or widowed are not active.
# - look like few people who were married voluntarily left maybe change in compnay or region.
